# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/Colab Notebooks/DataVerse/"
submission_file = "ML model/submission_multinomial_nb.csv"
test_file = "preprocessed_test_version_2_lemmatizer.csv"

submission_df = pd.read_csv(path + submission_file)
test_df = pd.read_csv(path + test_file)

# %%
# /content/drive/MyDrive/Colab Notebooks/DataVerse/preprocessed_data_lemmatizer.csv
train_df = pd.read_csv(path + "preprocessed_data_lemmatizer.csv")

# %%
# run for second time
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
le.fit(train_df["category"])

label = le.transform(train_df["category"])

# train_df["label"] = label
train_df.head()
# Out:
#            id category                                               text
# 0   2009.0642       cs  completely self supervised crowd counting via ...
# 1  2010.13821       cs  wavelet flow fast training high resolution nor...
# 2  1904.12782     math  transversally elliptic complex cohomological f...
# 3  2105.00878     math  malliavin rubel theorem small entire function ...
# 4  1906.04024     math  odd cycle game connected rule study positional...

# %%
label
# Out:
# array([ 3,  3, 12, ...,  3,  3, 17])

# %%
submission_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43785 entries, 0 to 43784
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        43785 non-null  object
#  1   category  43785 non-null  object
# dtypes: object(2)
# memory usage: 684.3+ KB

# %%
test_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43785 entries, 0 to 43784
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        43785 non-null  object
#  1   category  43785 non-null  object
#  2   text      43785 non-null  object
# dtypes: object(3)
# memory usage: 1.0+ MB

# %%
submission_category = le.transform(submission_df.category)
test_category = le.transform(test_df.category)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(submission_category, test_category))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.79      0.90      0.84      2660
#            2       0.68      0.77      0.72      3233
#            3       0.50      0.87      0.64      7613
#            4       0.54      0.20      0.29       542
#            5       0.72      0.27      0.39      4597
#            6       0.00      0.00      0.00         1
#            7       0.69      0.43      0.53      1268
#            8       0.43      0.37      0.40       437
#            9       0.51      0.34      0.41       192
#           10       0.49      0.52      0.50       927
#           11       0.47      0.43      0.45      1076
#           12       0.61      0.82      0.70      6785
#           13       0.62      0.15      0.24      2509
#           14       0.31      0.28      0.29       342
#           15       0.41      0.33      0.37       231
# ...
