# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
train_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataVerse/train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DataVerse/test.csv")

# %% [markdown]
# # Train Data Overview

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861236 entries, 0 to 861235
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        861236 non-null  object
#  1   title     861236 non-null  object
#  2   abstract  861236 non-null  object
#  3   category  861232 non-null  object
# dtypes: object(4)
# memory usage: 26.3+ MB

# %%
sample_train_data = train_data.sample(7)
sample_train_data
# Out:
#                 id                                              title  \
# 177813  2012.08209   Possible phase transition in plasma mirror modes
# 393226  2102.00193  Coupling innovation method and feasibility ana...
# 84798    1906.0761  Improving Sentiment Analysis with Multi-task L...
# 19018   1810.02767  Efficient Estimation of Smooth Functionals in ...
# 101001  2103.16966  Revisiting regular sequences in light of ratio...
# 239917  2012.15227  Interaction between vortex beams and diatomic ...
# 42      2007.14755  Learning Transferable Push Manipulation Skills...
#
#                                                  abstract category
# 177813    Mirror modes in collisionless high-temperatu...  physics
# 393226    In order to solve the recent defect in garba...       cs
# 84798     Sentiment analysis is directly affected by c...       cs
# 19018     We study a problem of estimation of smooth f...     stat
# 101001    Regular sequences generalize the extensively...       cs
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 861236 entries, 0 to 861235
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        861236 non-null  object
#  1   title     861236 non-null  object
#  2   abstract  861236 non-null  object
#  3   category  861232 non-null  object
# dtypes: object(4)
# memory usage: 26.3+ MB

# %%
for index, title, abstract, category in zip(sample_train_data.id, sample_train_data.title, sample_train_data.abstract, sample_train_data.category):
  print(category, index)
  print(title)
  print("-----------------")
  # print(abstract)
  print("================")
# Out:
# physics 2012.08209
# Possible phase transition in plasma mirror modes
# -----------------
# ...
# cs 2102.00193
# Coupling innovation method and feasibility analysis of garbage
#   classification
# -----------------
# ...
# cs 1906.0761
# Improving Sentiment Analysis with Multi-task Learning of Negation
# -----------------
# ...
# stat 1810.02767
# Efficient Estimation of Smooth Functionals in Gaussian Shift Models
# -----------------
# ...
# cs 2103.16966
# Revisiting regular sequences in light of rational base numeration
#   systems
# -----------------
# ...
# physics 2012.15227
# Interaction between vortex beams and diatomic molecules with rotation
# -----------------
# ...
# cs 2007.14755
# Learning Transferable Push Manipulation Skills in Novel Contexts
# -----------------
# ...

# %%
train_data.category.nunique()
# Out:
# 23

# %%
# !pip install matplotlib==3.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt

# %%
sns.set(rc={"figure.figsize":(20, 8)})
ax = sns.countplot(x="category", data = train_data)
ax.bar_label(ax.containers[0])
plt.show()

# %%
train_data.category.unique()
# Out:
# array(['cs', 'math', 'physics', 'eess', 'cond-mat', 'q-bio', 'stat',
#        'hep-ph', 'math-ph', 'hep-th', 'astro-ph', 'gr-qc', 'nlin',
#        'quant-ph', 'nucl-th', 'q-fin', 'nucl-ex', 'hep-ex', 'econ',
#        'hep-lat', 'funct-an', nan, 'alg-geom', 'q-alg'], dtype=object)

# %%
ax.bar_label(ax.containers[0])

# %% [markdown]
# # Test data

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45328 entries, 0 to 45327
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        45328 non-null  object
#  1   title     45328 non-null  object
#  2   abstract  45328 non-null  object
# dtypes: object(3)
# memory usage: 1.0+ MB

# %%
test_data.sample(7)
# Out:
#                id                                              title  \
# 15095   1910.1339  Ferromagnetic Kitaev interaction and the origi...
# 5601   1903.04377  SleepNet: Automated Sleep Analysis via Dense C...
# 2416   1810.01393  Approximating the Existential Theory of the Reals
# 25225  2006.12492  Analog of Menchov-Trokhimchuk theorem for mono...
# 42520  1908.09089  Web-enabled Intelligent System for Continuous ...
# 13220  2011.14826  Revisiting Rainbow: Promoting more Insightful ...
# 13281  2009.14295  Wall speed and shape in singlet-assisted stron...
#
#                                                 abstract
# 15095    $\alpha$-RuCl$_3$ is drawing much attention ...
# 5601     In this work, a dense recurrent convolutiona...
# 2416     The Existential Theory of the Reals (ETR) co...
# 25225    The aim of this work is to weaken the condit...
# 42520    A large number of sensors deployed in recent...
# 13220    Since the introduction of DQN, a vast majori...
# ...
